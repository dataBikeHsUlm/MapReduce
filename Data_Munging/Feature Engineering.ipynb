# %% [markdown]
# #### Feature Engineering ####
# The process of `feature engineering` includes following steps:
#
# - Brainstorming or Testing features;
# - Deciding what features to create;
# - Creating features;
# - Checking how the features work with your model;
# - Improving your features if needed;
# - Go back to brainstorming/creating more features until the work is done.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import holidays as hd
import calendar
from datetime import datetime, date
from pprint import pprint

# %%
cycle_usage = pd.read_csv("cycleusage_cleansed.csv")
cycle_usage.count()
# Out:
# StartStation Id               33927
# Start Date                    33927
# EndStation Id                 33927
# End Date                      33927
# Duration                      33927
# StartStation Id Used          33927
# EndStation Id Used            33927
# Frequency                     33927
# StartStation Address          33927
# StartStation latitude         33927
# StartStation longitude        33927
# StartStation capacity         33927
# EndStation Address            33927
# EndStation latitude           33927
# EndStation longitude          33927
# EndStation capacity           33927
# distance (geodesic)           33927
# Daily Weather                 33927
# Hourly Weather                33927
# Humidity                      33927
# Windspeed                     33927
# Apparent Temperature (Avg)    33927
# dtype: int64

# %%
cycle_usage[cycle_usage["StartStation Id"] == 191]
# Out:
#        StartStation Id        Start Date  EndStation Id          End Date  \
# 0                  191  04/09/2015 11:24            172  04/09/2015 11:41
# 1                  191  02/08/2015 16:23            172  02/08/2015 19:15
# 2                  191  23/10/2017 19:55            172  23/10/2017 20:13
# 3                  191  19/08/2016 21:14            172  19/08/2016 21:33
# 4                  191  07/08/2015 21:05            172  07/08/2015 21:25
# 5                  191  28/11/2017 11:19            223  28/11/2017 11:39
# 6                  191  21/06/2015 20:09            172  21/06/2015 20:30
# 7                  191  08/05/2016 19:55            223  08/05/2016 20:16
# 8                  191  21/06/2015 20:08            172  21/06/2015 20:30
# 9                  191  03/07/2017 19:51            223  03/07/2017 20:13
# 10                 191  25/04/2015 18:28            486  25/04/2015 18:50
# 11                 191  17/06/2017 21:33            172  17/06/2017 21:56
# 12                 191  11/08/2015 15:31            223  11/08/2015 15:54
# 13                 191  21/06/2015 20:06            172  21/06/2015 20:30
# 14                 191  11/08/2015 15:30            223  11/08/2015 15:54
# 15                 191  13/08/2016 23:18            172  13/08/2016 23:43
# 16                 191  11/04/2016 19:05            223  11/04/2016 19:30
# 17                 191  17/06/2017 21:29            172  17/06/2017 21:55
# 18                 191  20/08/2015 15:56            223  20/08/2015 16:22
# 19                 191  19/08/2017 20:01            172  19/08/2017 20:27
# 20                 191  19/08/2017 20:01            172  19/08/2017 20:27
# 21                 191  17/06/2017 21:29            172  17/06/2017 21:56
# 22                 191  30/03/2016 18:40            223  30/03/2016 19:07
# 23                 191  02/08/2015 14:41            172  02/08/2015 19:15
# 24                 191  17/06/2017 21:28            172  17/06/2017 21:56
# 25                 191  01/01/2018 03:12            172  01/01/2018 03:41
# 26                 191  12/08/2015 15:41            223  12/08/2015 16:10
# 27                 191  24/04/2016 12:36            172  24/04/2016 13:06
# 28                 191  16/07/2016 20:37            223  16/07/2016 21:07
# 29                 191  05/07/2018 22:03            172  05/07/2018 22:34
# ...                ...               ...            ...               ...
# 33897              191  06/07/2018 17:37             39  06/07/2018 18:13
# 33914             ...              Shoreditch High Street, Shoreditch
# 33915             ...              Shoreditch High Street, Shoreditch
# 33916             ...                   Lincoln's Inn Fields, Holborn
# 33917             ...              Shoreditch High Street, Shoreditch
# 33918             ...              Shoreditch High Street, Shoreditch
# 33919             ...              Shoreditch High Street, Shoreditch
# 33920             ...              Shoreditch High Street, Shoreditch
# 33921             ...                        Whiston Road, Haggerston
# 33922             ...                        Whiston Road, Haggerston
# 33923             ...              Shoreditch High Street, Shoreditch
# 33924             ...                   Lincoln's Inn Fields, Holborn
# 33925             ...              Shoreditch High Street, Shoreditch
# 33926             ...                   Lincoln's Inn Fields, Holborn
#
#        EndStation latitude EndStation longitude  EndStation capacity  \
# 0                51.491212            -0.173716                   19
# 1                51.491212            -0.173716                   19
# 2                51.491212            -0.173716                   19
# 3                51.491212            -0.173716                   19
# 4                51.491212            -0.173716                   19
# 5                51.491485            -0.090221                   24
# 6                51.491212            -0.173716                   19
# 7                51.491485            -0.090221                   24
# 8                51.491212            -0.173716                   19
# 9                51.491485            -0.090221                   24
# 10               51.525645            -0.069543                   37
# 11               51.491212            -0.173716                   19
# 12               51.491485            -0.090221                   24
# 13               51.491212            -0.173716                   19
# 14               51.491485            -0.090221                   24
# 15               51.491212            -0.173716                   19
# 16               51.491485            -0.090221                   24
# 17               51.491212            -0.173716                   19
# 18               51.491485            -0.090221                   24
# 19               51.491212            -0.173716                   19
# 20               51.491212            -0.173716                   19
# 21               51.491212            -0.173716                   19
# 22               51.491485            -0.090221                   24
# 23               51.491212            -0.173716                   19
# 24               51.491212            -0.173716                   19
# 25               51.491212            -0.173716                   19
# 26               51.491485            -0.090221                   24
# 27               51.491212            -0.173716                   19
# 28               51.491485            -0.090221                   24
# 29               51.491212            -0.173716                   19
# ...                    ...                  ...                  ...
# 33897            51.526378            -0.078131                   41
# 33898            51.526378            -0.078131                   41
# 33899            51.526378            -0.078131                   41
# 33900            51.526378            -0.078131                   41
# 33901            51.526378            -0.078131                   41
# 33902            51.526378            -0.078131                   41
# 33903            51.534464            -0.076341                   21
# 33904            51.516278            -0.118273                   28
# 33905            51.516278            -0.118273                   28
# 33906            51.526378            -0.078131                   41
# 33907            51.526378            -0.078131                   41
# 33908            51.516278            -0.118273                   28
# 33909            51.526378            -0.078131                   41
# 33910            51.526378            -0.078131                   41
# 33911            51.526378            -0.078131                   41
# 33912            51.526378            -0.078131                   41
# 33913            51.526378            -0.078131                   41
# 33914            51.526378            -0.078131                   41
# 33915            51.526378            -0.078131                   41
# 33916            51.516278            -0.118273                   28
# 33917            51.526378            -0.078131                   41
# 33918            51.526378            -0.078131                   41
# 33919            51.526378            -0.078131                   41
# 33920            51.526378            -0.078131                   41
# 33921            51.534464            -0.076341                   21
# 33922            51.534464            -0.076341                   21
# 33923            51.526378            -0.078131                   41
# 33924            51.516278            -0.118273                   28
# 33925            51.526378            -0.078131                   41
# 33926            51.516278            -0.118273                   28
#
#        distance (geodesic)        Daily Weather  \
# 0                 1.929121    partly-cloudy-day
# 1                 1.929121  partly-cloudy-night
# 2                 1.929121    partly-cloudy-day
# 3                 1.929121    partly-cloudy-day
# 4                 1.929121    partly-cloudy-day
# 5                 4.582428    partly-cloudy-day
# 6                 1.929121    partly-cloudy-day
# 7                 4.582428            clear-day
# 8                 1.929121    partly-cloudy-day
# 9                 4.582428    partly-cloudy-day
# 10                6.345569    partly-cloudy-day
# 11                1.929121    partly-cloudy-day
# 12                4.582428    partly-cloudy-day
# 13                1.929121    partly-cloudy-day
# 14                4.582428    partly-cloudy-day
# 15                1.929121    partly-cloudy-day
# 16                4.582428    partly-cloudy-day
# 17                1.929121    partly-cloudy-day
# 18                4.582428    partly-cloudy-day
# 19                1.929121    partly-cloudy-day
# 20                1.929121    partly-cloudy-day
# 21                1.929121    partly-cloudy-day
# 22                4.582428    partly-cloudy-day
# 23                1.929121  partly-cloudy-night
# 24                1.929121    partly-cloudy-day
# 25                1.929121  partly-cloudy-night
# 26                4.582428    partly-cloudy-day
# 27                1.929121    partly-cloudy-day
# 28                4.582428    partly-cloudy-day
# 29                1.929121    partly-cloudy-day
# ...                    ...                  ...
# 33897             5.838299    partly-cloudy-day
# 33898             5.838299            clear-day
# 33899             5.838299    partly-cloudy-day
# 33900             5.838299    partly-cloudy-day
# 33901             5.838299    partly-cloudy-day
# 33902             5.838299    partly-cloudy-day
# 33903             6.392367    partly-cloudy-day
# 33904             2.851682    partly-cloudy-day
# 33905             2.851682    partly-cloudy-day
# 33906             5.838299    partly-cloudy-day
# 33907             5.838299    partly-cloudy-day
# 33908             2.851682    partly-cloudy-day
# 33909             5.838299    partly-cloudy-day
# 33910             5.838299    partly-cloudy-day
# 33911             5.838299            clear-day
# 33912             5.838299    partly-cloudy-day
# 33913             5.838299    partly-cloudy-day
# 33914             5.838299    partly-cloudy-day
# 33915             5.838299    partly-cloudy-day
# 33916             2.851682                 wind
# 33917             5.838299    partly-cloudy-day
# 33918             5.838299    partly-cloudy-day
# 33919             5.838299    partly-cloudy-day
# 33920             5.838299    partly-cloudy-day
# 33921             6.392367                  fog
# 33922             6.392367                  fog
# 33923             5.838299                  fog
# 33924             2.851682    partly-cloudy-day
# 33925             5.838299    partly-cloudy-day
# 33926             2.851682    partly-cloudy-day
#
#                                           Hourly Weather Humidity Windspeed  \
# 0      [{'time': 1441321200, 'summary': 'Partly Cloud...     0.76      1.62
# 1      [{'time': 1438470000, 'summary': 'Clear', 'ico...     0.65      1.86
# 2      [{'time': 1508713200, 'summary': 'Overcast', '...     0.89      3.17
# 3      [{'time': 1471561200, 'summary': 'Partly Cloud...     0.88      2.57
# 4      [{'time': 1438902000, 'summary': 'Clear', 'ico...     0.67      0.41
# 5      [{'time': 1511827200, 'summary': 'Clear', 'ico...     0.82      2.97
# 6      [{'time': 1434841200, 'summary': 'Mostly Cloud...     0.70      3.76
# 7      [{'time': 1462662000, 'summary': 'Clear', 'ico...     0.55      2.89
# 8      [{'time': 1434841200, 'summary': 'Mostly Cloud...     0.70      3.76
# 9      [{'time': 1499036400, 'summary': 'Clear', 'ico...     0.70      3.07
# 10     [{'time': 1429916400, 'summary': 'Mostly Cloud...     0.80      4.61
# 11     [{'time': 1497654000, 'summary': 'Partly Cloud...     0.69      1.44
# 12     [{'time': 1439247600, 'summary': 'Clear', 'ico...     0.75      0.12
# 13     [{'time': 1434841200, 'summary': 'Mostly Cloud...     0.70      3.76
# 14     [{'time': 1439247600, 'summary': 'Clear', 'ico...     0.75      0.12
# 15     [{'time': 1471042800, 'summary': 'Clear', 'ico...     0.70      3.03
# 16     [{'time': 1460329200, 'summary': 'Mostly Cloud...     0.82      1.65
# 17     [{'time': 1497654000, 'summary': 'Partly Cloud...     0.69      1.44
# 18     [{'time': 1440025200, 'summary': 'Light Rain',...     0.87      2.39
# 19     [{'time': 1503097200, 'summary': 'Partly Cloud...     0.69      5.08
# 20     [{'time': 1503097200, 'summary': 'Partly Cloud...     0.69      5.08
# 21     [{'time': 1497654000, 'summary': 'Partly Cloud...     0.69      1.44
# 22     [{'time': 1459292400, 'summary': 'Partly Cloud...     0.75      2.68
# 23     [{'time': 1438470000, 'summary': 'Clear', 'ico...     0.65      1.86
# 24     [{'time': 1497654000, 'summary': 'Partly Cloud...     0.69      1.44
# 25     [{'time': 1514764800, 'summary': 'Mostly Cloud...     0.81      5.07
# 26     [{'time': 1439334000, 'summary': 'Clear', 'ico...     0.76      2.74
# 27     [{'time': 1461452400, 'summary': 'Partly Cloud...     0.69      2.47
# 28     [{'time': 1468623600, 'summary': 'Overcast', '...     0.76      3.73
# 29     [{'time': 1530745200, 'summary': 'Mostly Cloud...     0.60      2.89
# ...                                                  ...      ...       ...
# 33897  [{'time': 1530831600, 'summary': 'Clear', 'ico...     0.58      3.59
# 33898  [{'time': 1502578800, 'summary': 'Clear', 'ico...     0.61      1.30
# 33899  [{'time': 1471302000, 'summary': 'Clear', 'ico...     0.73      2.19
# 33900  [{'time': 1532300400, 'summary': 'Clear', 'ico...     0.53      6.27
# 33901  [{'time': 1491087600, 'summary': 'Partly Cloud...     0.75      1.37
# 33902  [{'time': 1474758000, 'summary': 'Clear', 'ico...     0.71      3.27
# 33903  [{'time': 1434668400, 'summary': 'Clear', 'ico...     0.63      2.73
# 33904  [{'time': 1469833200, 'summary': 'Mostly Cloud...     0.73      1.38
# 33905  [{'time': 1469833200, 'summary': 'Mostly Cloud...     0.73      1.38
# 33906  [{'time': 1475967600, 'summary': 'Mostly Cloud...     0.80      2.16
# 33907  [{'time': 1499036400, 'summary': 'Clear', 'ico...     0.70      3.07
# 33908  [{'time': 1524438000, 'summary': 'Clear', 'ico...     0.71      4.68
# 33909  [{'time': 1510963200, 'summary': 'Overcast', '...     0.86      2.57
# 33910  [{'time': 1510963200, 'summary': 'Overcast', '...     0.86      2.57
# 33911  [{'time': 1535842800, 'summary': 'Clear', 'ico...     0.61      4.26
# 33912  [{'time': 1510963200, 'summary': 'Overcast', '...     0.86      2.57
# 33913  [{'time': 1530313200, 'summary': 'Clear', 'ico...     0.58      9.95
# 33914  [{'time': 1435359600, 'summary': 'Mostly Cloud...     0.64      2.55
# 33915  [{'time': 1504911600, 'summary': 'Clear', 'ico...     0.82      2.52
# 33916  [{'time': 1532732400, 'summary': 'Mostly Cloud...     0.63     14.90
# 33917  [{'time': 1464217200, 'summary': 'Overcast', '...     0.72      0.80
# 33918  [{'time': 1464217200, 'summary': 'Overcast', '...     0.72      0.80
# 33919  [{'time': 1532127600, 'summary': 'Partly Cloud...     0.63      3.46
# 33920  [{'time': 1434582000, 'summary': 'Partly Cloud...     0.63      3.35
# 33921  [{'time': 1477782000, 'summary': 'Foggy', 'ico...     0.94      0.29
# 33922  [{'time': 1477782000, 'summary': 'Foggy', 'ico...     0.94      0.29
# 33923  [{'time': 1477782000, 'summary': 'Foggy', 'ico...     0.94      0.29
# 33924  [{'time': 1497049200, 'summary': 'Clear', 'ico...     0.71      5.09
# 33925  [{'time': 1523833200, 'summary': 'Mostly Cloud...     0.71      5.00
# 33926  [{'time': 1530658800, 'summary': 'Partly Cloud...     0.64      4.17
#
#        Apparent Temperature (Avg)
# 0                           53,95
# 1                          69,165
# 2                          59,145
# 3                           62,46
# 4                           66,11
# 5                          36,725
# 6                           60,33
# 7                          68,235
# 8                           60,33
# 9                           64,69
# 10                         54,805
# 11                          73,76
# 12                          64,59
# 13                          60,33
# 14                          64,59
# 15                           67,6
# 16                          52,02
# 17                          73,76
# 18                         67,715
# 19                         58,925
# 20                         58,925
# 21                          73,76
# 22                          47,25
# 23                         69,165
# 24                          73,76
# 25                          40,93
# 26                         66,255
# 27                          45,22
# 28                          72,32
# 29                             72
# ...                           ...
# 33897                      73,785
# 33898                      61,395
# 33899                      64,285
# 33900                      75,355
# 33901                      51,295
# 33902                      58,215
# 33903                      61,705
# 33904                       63,14
# 33905                       63,14
# 33906                      50,715
# 33907                       64,69
# 33908                        56,7
# 33909                       42,25
# 33910                       42,25
# 33911                      62,625
# 33912                       42,25
# 33913                       69,73
# 33914                       67,29
# 33915                        55,9
# 33916                       66,77
# 33917                       59,32
# 33918                       59,32
# 33919                       70,61
# 33920                       60,55
# 33921                      52,015
# 33922                      52,015
# 33923                      52,015
# 33924                      67,505
# 33925                      53,465
# 33926                      69,795
#
# [33927 rows x 22 columns]

# %%
rm_columns = {
    #"StartStation Id",
    #"Start Date",
    "StartStation Address",
   # "StartStation capacity",
    #"EndStation Id",
    "End Date",
    "EndStation Address",
   # "EndStation capacity",
   # "Duration",
   # "Frequency",
  #  "Humidity",
   # "Windspeed",
  #  "Apparent Temperature (Avg)",
    "StartStation Id Used",
    "EndStation Id Used",
    "StartStation latitude",
    "StartStation longitude",
    "EndStation latitude",
    "EndStation longitude",
    "Hourly Weather",
   # "distance (geodesic)"
   # "Daily Weather"
}

cycle_usage.drop(columns=rm_columns, inplace=True)
cycle_usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33927 entries, 0 to 33926
# Data columns (total 12 columns):
# StartStation Id               33927 non-null int64
# Start Date                    33927 non-null object
# EndStation Id                 33927 non-null int64
# Duration                      33927 non-null int64
# Frequency                     33927 non-null int64
# StartStation capacity         33927 non-null int64
# EndStation capacity           33927 non-null int64
# distance (geodesic)           33927 non-null float64
# Daily Weather                 33927 non-null object
# Humidity                      33927 non-null float64
# Windspeed                     33927 non-null float64
# Apparent Temperature (Avg)    33927 non-null object
# dtypes: float64(3), int64(6), object(3)
# memory usage: 3.1+ MB

# %%
# Check for empty values and empty strings
np.where(pd.isnull(cycle_usage))
np.where(cycle_usage.applymap(lambda x: x == ''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# #### Darksky note:#####
# > Our system is presently very simple: it finds the “worst” weather condition that will happen during the day (4AM to 4AM), and uses the icon for it. The only case where a daily icon will show a *-night value is partly-cloudy-night, and this is done to match the daily summary text. We already have intentions to change this behavior, because it is confusing.
# In the meantime, you can assume that if partly-cloudy-night is the worst weather condition that was found, that it was clear during the day. So you can just treat partly-cloudy-night as an alias for clear-day.

# %%
#print(cycle_usage.iloc[452861]["Start Date"][:10], cycle_usage.iloc[452861]["Start Date"][-5:])

# %%
cycle_usage.groupby(by="Daily Weather").count()
cycle_usage["Daily Weather"].loc[cycle_usage["Daily Weather"]=="partly-cloudy-night"] = "clear-day"

# %%
# Inconsistent dates e.g. 00:00 01:25:00
#cycle_usage.iloc[452861]
for index, p in cycle_usage.iterrows():
    if (len(p["Start Date"]) == 19):
      #  print(index, p["Start Date"])
        cycle_usage["Start Date"].iloc[index] = p["Start Date"][:16]
    elif (len(p["Start Date"]) > 19):
        print("anomaly", index, p["Start Date"])
        cycle_usage["Start Date"].iloc[index] = p["Start Date"][:10] + " " +p["Start Date"][-5:]

cycle_usage.dropna(inplace=True)
cycle_usage.count()
# Out:
# StartStation Id               33927
# Start Date                    33927
# EndStation Id                 33927
# Duration                      33927
# Frequency                     33927
# StartStation capacity         33927
# EndStation capacity           33927
# distance (geodesic)           33927
# Daily Weather                 33927
# Humidity                      33927
# Windspeed                     33927
# Apparent Temperature (Avg)    33927
# dtype: int64

# %% [markdown]
# Adding weekdays (Monday, Tuesday...)

# %%
#Add weekdays
cycle_usage["Start Date"] =  pd.to_datetime(cycle_usage["Start Date"], format='%d/%m/%Y %H:%M')
cycle_usage['Weekday'] = cycle_usage.apply(lambda row: calendar.day_name[row["Start Date"].weekday()],axis=1)

# %%
cycle_usage.head()
# Out:
#    StartStation Id          Start Date  EndStation Id  Duration  Frequency  \
# 0              191 2015-09-04 11:24:00            172      1020        104
# 1              191 2015-08-02 16:23:00            172     10320        104
# 2              191 2017-10-23 19:55:00            172      1080        104
# 3              191 2016-08-19 21:14:00            172      1140        104
# 4              191 2015-08-07 21:05:00            172      1200        104
#
#    StartStation capacity  EndStation capacity  distance (geodesic)  \
# 0                     28                   19             1.929121
# 1                     28                   19             1.929121
# 2                     28                   19             1.929121
# 3                     28                   19             1.929121
# 4                     28                   19             1.929121
#
#        Daily Weather  Humidity  Windspeed Apparent Temperature (Avg) Weekday
# 0  partly-cloudy-day      0.76       1.62                      53,95  Friday
# 1          clear-day      0.65       1.86                     69,165  Sunday
# 2  partly-cloudy-day      0.89       3.17                     59,145  Monday
# 3  partly-cloudy-day      0.88       2.57                      62,46  Friday
# 4  partly-cloudy-day      0.67       0.41                      66,11  Friday

# %% [markdown]
# `Meteorologische Jahreszeiten` <br>
# Nördliche Hemisphäre <br>
# Frühling: 1. März bis 31. Mai <br>
# Sommer: 1. Juni bis 31. August <br>
# Herbst: 1. September bis 30. November <br>
# Winter: 1. Dezember bis 28. Februar <br>

# %%
#Add seasons
def seasons(p):
    """Get meteorological season"""
    year = int(str(p["Start Date"])[:4])
    date_m = p["Start Date"]
    if date_m >= datetime(year, 3, 1, 0,0,0) and date_m <= datetime(year, 5, 31, 23,59,59):
        return "Spring"
    elif date_m >= datetime(year, 6, 1, 0,0,0) and date_m <= datetime(year, 8, 31, 23,59,59):
        return "Summer"
    elif date_m >= datetime(year, 9, 1, 0,0,0) and date_m <= datetime(year, 11, 30, 23,59,59):
        return "Autumn"
    elif date_m >= datetime(year, 12, 1, 0,0,0) or date_m < datetime(year, 3, 1, 23,59,59):
        return "Winter"
        
cycle_usage['Season'] = cycle_usage.apply(lambda row: seasons(row),axis=1)
cycle_usage.head()
# Out:
#    StartStation Id          Start Date  EndStation Id  Duration  Frequency  \
# 0              191 2015-09-04 11:24:00            172      1020        104
# 1              191 2015-08-02 16:23:00            172     10320        104
# 2              191 2017-10-23 19:55:00            172      1080        104
# 3              191 2016-08-19 21:14:00            172      1140        104
# 4              191 2015-08-07 21:05:00            172      1200        104
#
#    StartStation capacity  EndStation capacity  distance (geodesic)  \
# 0                     28                   19             1.929121
# 1                     28                   19             1.929121
# 2                     28                   19             1.929121
# 3                     28                   19             1.929121
# 4                     28                   19             1.929121
#
#        Daily Weather  Humidity  Windspeed Apparent Temperature (Avg) Weekday  \
# 0  partly-cloudy-day      0.76       1.62                      53,95  Friday
# 1          clear-day      0.65       1.86                     69,165  Sunday
# 2  partly-cloudy-day      0.89       3.17                     59,145  Monday
# 3  partly-cloudy-day      0.88       2.57                      62,46  Friday
# 4  partly-cloudy-day      0.67       0.41                      66,11  Friday
#
#    Season
# 0  Autumn
# 1  Summer
# 2  Autumn
# 3  Summer
# 4  Summer

# %% [markdown]
#  ##### Day & Night cycle ####
#  After 6 pm night, after 6 am day → “Day” & “Night”

# %%
#Day night state
def daynight(p):
    """Returns day or night depending on clock"""
    timeclock = p["Start Date"].hour
    if timeclock > 6 and timeclock < 18:
        return "day"
    else:
        return "night"       
cycle_usage["Day & Night"] = cycle_usage.apply(lambda row: daynight(row), axis=1)

# %% [markdown]
# ###### Holidays ######
# Check if that day is a specific holiday?

# %%
#Consider holidays (e.g. Good Friday in UK)
def holiday(p):
    """ Checks if holiday """
    uk_holidays = hd.UK()
    if (p["Start Date"].date() in uk_holidays):
        return True
    else:
        return False
    
for date2, name in sorted(hd.UK(state='London', years=[2015,2016,2017], observed=False).items()):
    print(date2, name)
    
cycle_usage["Holiday"] = cycle_usage.apply(lambda row: holiday(row), axis=1)            
cycle_usage.head()
# Out:
# 2015-01-01 New Year's Day
# 2015-01-02 New Year Holiday [Scotland]
# 2015-03-17 St. Patrick's Day [Northern Ireland]
# 2015-04-03 Good Friday
# 2015-04-06 Easter Monday [England, Wales, Northern Ireland]
# 2015-05-04 May Day
# 2015-05-25 Spring Bank Holiday
# 2015-07-12 Battle of the Boyne [Northern Ireland]
# 2015-08-03 Summer Bank Holiday [Scotland]
# 2015-08-31 Late Summer Bank Holiday [England, Wales, Northern Ireland]
# 2015-11-30 St. Andrew's Day [Scotland]
# 2015-12-25 Christmas Day
# 2015-12-26 Boxing Day
# 2016-01-01 New Year's Day
# 2016-01-02 New Year Holiday [Scotland]
# 2016-03-17 St. Patrick's Day [Northern Ireland]
# 2016-03-25 Good Friday
# 2016-03-28 Easter Monday [England, Wales, Northern Ireland]
# 2016-05-02 May Day
# 2016-05-30 Spring Bank Holiday
# 2016-07-12 Battle of the Boyne [Northern Ireland]
# 2016-08-01 Summer Bank Holiday [Scotland]
# 2016-08-29 Late Summer Bank Holiday [England, Wales, Northern Ireland]
# 2016-11-30 St. Andrew's Day [Scotland]
# 2016-12-25 Christmas Day
# 2016-12-26 Boxing Day
# 2017-01-01 New Year's Day
# 2017-01-02 New Year Holiday [Scotland]
# 2017-03-17 St. Patrick's Day [Northern Ireland]
# 2017-04-14 Good Friday
# 2017-04-17 Easter Monday [England, Wales, Northern Ireland]
# 2017-05-01 May Day
# 2017-05-29 Spring Bank Holiday
# 2017-07-12 Battle of the Boyne [Northern Ireland]
# 2017-08-07 Summer Bank Holiday [Scotland]
# 2017-08-28 Late Summer Bank Holiday [England, Wales, Northern Ireland]
# 2017-11-30 St. Andrew's Day [Scotland]
# 2017-12-25 Christmas Day
# 2017-12-26 Boxing Day
#    StartStation Id          Start Date  EndStation Id  Duration  Frequency  \
# 0              191 2015-09-04 11:24:00            172      1020        104
# 1              191 2015-08-02 16:23:00            172     10320        104
# 2              191 2017-10-23 19:55:00            172      1080        104
# 3              191 2016-08-19 21:14:00            172      1140        104
# 4              191 2015-08-07 21:05:00            172      1200        104
#
#    StartStation capacity  EndStation capacity  distance (geodesic)  \
# 0                     28                   19             1.929121
# 1                     28                   19             1.929121
# 2                     28                   19             1.929121
# 3                     28                   19             1.929121
# 4                     28                   19             1.929121
#
#        Daily Weather  Humidity  Windspeed Apparent Temperature (Avg) Weekday  \
# 0  partly-cloudy-day      0.76       1.62                      53,95  Friday
# 1          clear-day      0.65       1.86                     69,165  Sunday
# 2  partly-cloudy-day      0.89       3.17                     59,145  Monday
# 3  partly-cloudy-day      0.88       2.57                      62,46  Friday
# 4  partly-cloudy-day      0.67       0.41                      66,11  Friday
#
#    Season Day & Night  Holiday
# 0  Autumn         day    False
# 1  Summer         day    False
# 2  Autumn       night    False
# 3  Summer       night    False
# 4  Summer       night    False

# %%
# Months
def months_names(p):
    """Returns month name"""
    months = {
        1: "January",
        2: "February",
        3: "March",
        4: "April",
        5: "May",
        6: "June",
        7: "July",
        8: "August",
        9: "September",
        10: "October",
        11: "November",
        12: "December"
    }
    return months.get(p["Start Date"].month, "not defined")

cycle_usage["Month"] = cycle_usage.apply(lambda row: months_names(row), axis=1)

# %% [markdown]
# ##### Split Start Date #####
# > Dates are difficult to handle for ML. Idea: splitting to several columns

# %%
#Extract only dd-mm-YYYY
cycle_usage['Date'] = cycle_usage.apply(lambda row: str(row["Start Date"])[:10], axis=1)
cycle_usage['Date'] = pd.to_datetime(cycle_usage.Date, format="%Y/%m/%d")
#Extracting Year
cycle_usage['Year'] = cycle_usage['Date'].dt.year
#Extracting Month
cycle_usage['Month'] = cycle_usage['Date'].dt.month
#Extracting passed years since the date
cycle_usage['Passed_Years'] = date.today().year - cycle_usage['Date'].dt.year
#Extracting passed months since the date
cycle_usage['Passed_Months'] = (date.today().year - cycle_usage['Date'].dt.year) * 12 + date.today().month - cycle_usage['Date'].dt.month
cycle_usage.head()
# Out:
#    StartStation Id          Start Date  EndStation Id  Duration  Frequency  \
# 0              191 2015-09-04 11:24:00            172      1020        104
# 1              191 2015-08-02 16:23:00            172     10320        104
# 2              191 2017-10-23 19:55:00            172      1080        104
# 3              191 2016-08-19 21:14:00            172      1140        104
# 4              191 2015-08-07 21:05:00            172      1200        104
#
#    StartStation capacity  EndStation capacity  distance (geodesic)  \
# 0                     28                   19             1.929121
# 1                     28                   19             1.929121
# 2                     28                   19             1.929121
# 3                     28                   19             1.929121
# 4                     28                   19             1.929121
#
#        Daily Weather  Humidity      ...        Apparent Temperature (Avg)  \
# 0  partly-cloudy-day      0.76      ...                             53,95
# 1          clear-day      0.65      ...                            69,165
# 2  partly-cloudy-day      0.89      ...                            59,145
# 3  partly-cloudy-day      0.88      ...                             62,46
# 4  partly-cloudy-day      0.67      ...                             66,11
#
#   Weekday  Season Day & Night Holiday  Month       Date  Year  Passed_Years  \
# 0  Friday  Autumn         day   False      9 2015-09-04  2015             4
# 1  Sunday  Summer         day   False      8 2015-08-02  2015             4
# 2  Monday  Autumn       night   False     10 2017-10-23  2017             2
# 3  Friday  Summer       night   False      8 2016-08-19  2016             3
# 4  Friday  Summer       night   False      8 2015-08-07  2015             4
#
#    Passed_Months
# 0             43
# 1             44
# 2             18
# 3             32
# 4             44
#
# [5 rows x 21 columns]

# %%
cycle_usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33927 entries, 0 to 33926
# Data columns (total 21 columns):
# StartStation Id               33927 non-null int64
# Start Date                    33927 non-null datetime64[ns]
# EndStation Id                 33927 non-null int64
# Duration                      33927 non-null int64
# Frequency                     33927 non-null int64
# StartStation capacity         33927 non-null int64
# EndStation capacity           33927 non-null int64
# distance (geodesic)           33927 non-null float64
# Daily Weather                 33927 non-null object
# Humidity                      33927 non-null float64
# Windspeed                     33927 non-null float64
# Apparent Temperature (Avg)    33927 non-null object
# Weekday                       33927 non-null object
# Season                        33927 non-null object
# Day & Night                   33927 non-null object
# Holiday                       33927 non-null bool
# Month                         33927 non-null int64
# Date                          33927 non-null datetime64[ns]
# Year                          33927 non-null int64
# Passed_Years                  33927 non-null int64
# Passed_Months                 33927 non-null int64
# dtypes: bool(1), datetime64[ns](2), float64(3), int64(10), object(5)
# memory usage: 5.5+ MB

# %%
rm_columns = {
    #"StartStation Id",
    "Start Date",
    "StartStation Address",
    "StartStation capacity",
    #"EndStation Id",
    "End Date",
    "EndStation Address",
    "EndStation capacity",
    "Duration",
    "Frequency",
   # "Humidity",
   # "Windspeed",
   # "Apparent Temperature (Avg)",
    "StartStation Id Used",
    "EndStation Id Used",
    "StartStation latitude",
    "StartStation longitude",
    "EndStation latitude",
    "EndStation longitude",
    "Hourly Weather",
   # "distance (geodesic)"
   # "Daily Weather"
}

cycle_usage.drop(columns=rm_columns, inplace=True, errors="ignore")
#cycle_usage.drop_duplicates(inplace=True)
cycle_usage.head()
# Out:
#    StartStation Id  EndStation Id  distance (geodesic)      Daily Weather  \
# 0              191            172             1.929121  partly-cloudy-day
# 1              191            172             1.929121          clear-day
# 2              191            172             1.929121  partly-cloudy-day
# 3              191            172             1.929121  partly-cloudy-day
# 4              191            172             1.929121  partly-cloudy-day
#
#    Humidity  Windspeed Apparent Temperature (Avg) Weekday  Season Day & Night  \
# 0      0.76       1.62                      53,95  Friday  Autumn         day
# 1      0.65       1.86                     69,165  Sunday  Summer         day
# 2      0.89       3.17                     59,145  Monday  Autumn       night
# 3      0.88       2.57                      62,46  Friday  Summer       night
# 4      0.67       0.41                      66,11  Friday  Summer       night
#
#    Holiday  Month       Date  Year  Passed_Years  Passed_Months
# 0    False      9 2015-09-04  2015             4             43
# 1    False      8 2015-08-02  2015             4             44
# 2    False     10 2017-10-23  2017             2             18
# 3    False      8 2016-08-19  2016             3             32
# 4    False      8 2015-08-07  2015             4             44

# %%
cycle_usage.count()
# Out:
# StartStation Id               33927
# EndStation Id                 33927
# distance (geodesic)           33927
# Daily Weather                 33927
# Humidity                      33927
# Windspeed                     33927
# Apparent Temperature (Avg)    33927
# Weekday                       33927
# Season                        33927
# Day & Night                   33927
# Holiday                       33927
# Month                         33927
# Date                          33927
# Year                          33927
# Passed_Years                  33927
# Passed_Months                 33927
# dtype: int64

# %%
# Calculate new frequency of rented bikes
cycle_usage = pd.merge(cycle_usage, cycle_usage.groupby(["Date"])["Humidity"].count().reset_index(name="Frequency"), how='left', on="Date", 
         left_index=False, right_index=False, sort=True)

# %%
#cycle_usage.iloc[67]

# %%
#Get the most frequently occurring record
cycle_usage.groupby(by="StartStation Id").count().sort_values("Frequency", ascending=False).head(1)
# Out:
#                  EndStation Id  distance (geodesic)  Daily Weather  Humidity  \
# StartStation Id
# 191                      33927                33927          33927     33927
#
#                  Windspeed  Apparent Temperature (Avg)  Weekday  Season  \
# StartStation Id
# 191                  33927                       33927    33927   33927
#
#                  Day & Night  Holiday  Month   Date   Year  Passed_Years  \
# StartStation Id
# 191                    33927    33927  33927  33927  33927         33927
#
#                  Passed_Months  Frequency
# StartStation Id
# 191                      33927      33927

# %%
cycle_usage = cycle_usage[cycle_usage["StartStation Id"] == 191]

# %%
cycle_usage.to_csv("features.csv", header=True, index=False)
