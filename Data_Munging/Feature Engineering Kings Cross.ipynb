# %% [markdown]
# #### Feature Engineering ####
# The process of `feature engineering` includes following steps:
#
# - Brainstorming or Testing features;
# - Deciding what features to create;
# - Creating features;
# - Checking how the features work with your model;
# - Improving your features if needed;
# - Go back to brainstorming/creating more features until the work is done.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import requests
import json
import holidays as hd
import calendar
from datetime import datetime, date
from pprint import pprint

# %%
cycle_usage = pd.read_csv("cycleusage_cleansed2.csv")
cycle_usage.count()
# Out:
# StartStation Id               334019
# Start Date                    334019
# EndStation Id                 334019
# End Date                      334019
# Duration                      334019
# StartStation Id Used          334019
# EndStation Id Used            334019
# Frequency                     334019
# StartStation Address          334019
# StartStation latitude         334019
# StartStation longitude        334019
# StartStation capacity         334019
# EndStation Address            334019
# EndStation latitude           334019
# EndStation longitude          334019
# EndStation capacity           334019
# distance (geodesic)           334019
# Daily Weather                 334019
# Hourly Weather                334019
# Humidity                      334019
# Windspeed                     334019
# Apparent Temperature (Avg)    334019
# dtype: int64

# %%
cycle_usage.head()
# Out:
#    StartStation Id        Start Date  EndStation Id          End Date  \
# 0               14  02/04/2016 15:52             89  02/04/2016 15:54
# 1               14  04/04/2016 11:21             89  04/04/2016 11:23
# 2               14  04/04/2016 11:43             89  04/04/2016 11:46
# 3               14  06/04/2016 01:07             89  06/04/2016 01:10
# 4               14  06/04/2016 18:46             89  06/04/2016 18:49
#
#    Duration  StartStation Id Used  EndStation Id Used  Frequency  \
# 0       120                348832                1310       1265
# 1       120                348832                1310       1265
# 2       180                348832                1310       1265
# 3       180                348832                1310       1265
# 4       180                348832                1310       1265
#
#              StartStation Address  StartStation latitude  \
# 0  Belgrove Street , King's Cross              51.529944
# 1  Belgrove Street , King's Cross              51.529944
# 2  Belgrove Street , King's Cross              51.529944
# 3  Belgrove Street , King's Cross              51.529944
# 4  Belgrove Street , King's Cross              51.529944
#
#               ...                       EndStation Address  \
# 0             ...              Tavistock Place, Bloomsbury
# 1             ...              Tavistock Place, Bloomsbury
# 2             ...              Tavistock Place, Bloomsbury
# 3             ...              Tavistock Place, Bloomsbury
# 4             ...              Tavistock Place, Bloomsbury
#
#    EndStation latitude EndStation longitude  EndStation capacity  \
# 0             51.52625             -0.12351                   19
# 1             51.52625             -0.12351                   19
# 2             51.52625             -0.12351                   19
# 3             51.52625             -0.12351                   19
# 4             51.52625             -0.12351                   19
#
#    distance (geodesic)      Daily Weather  \
# 0              0.41099                fog
# 1              0.41099  partly-cloudy-day
# 2              0.41099  partly-cloudy-day
# 3              0.41099  partly-cloudy-day
# 4              0.41099  partly-cloudy-day
#
#                                       Hourly Weather Humidity Windspeed  \
# 0  [{'time': 1459551600, 'summary': 'Clear', 'ico...     0.67      2.96
# 1  [{'time': 1459724400, 'summary': 'Mostly Cloud...     0.83      3.26
# 2  [{'time': 1459724400, 'summary': 'Mostly Cloud...     0.83      3.26
# 3  [{'time': 1459897200, 'summary': 'Clear', 'ico...     0.72      5.21
# 4  [{'time': 1459897200, 'summary': 'Clear', 'ico...     0.72      5.21
#
#    Apparent Temperature (Avg)
# 0                      52,035
# 1                      50,025
# 2                      50,025
# 3                       46,15
# 4                       46,15
#
# [5 rows x 22 columns]

# %%
rm_columns = {
    #"StartStation Id",
    #"Start Date",
    "StartStation Address",
   # "StartStation capacity",
    #"EndStation Id",
    "End Date",
    "EndStation Address",
   # "EndStation capacity",
   # "Duration",
   # "Frequency",
  #  "Humidity",
   # "Windspeed",
  #  "Apparent Temperature (Avg)",
    "StartStation Id Used",
    "EndStation Id Used",
    "StartStation latitude",
    "StartStation longitude",
    "EndStation latitude",
    "EndStation longitude",
    "Hourly Weather",
   # "distance (geodesic)"
   # "Daily Weather"
}

cycle_usage.drop(columns=rm_columns, inplace=True)
cycle_usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334019 entries, 0 to 334018
# Data columns (total 12 columns):
# StartStation Id               334019 non-null int64
# Start Date                    334019 non-null object
# EndStation Id                 334019 non-null int64
# Duration                      334019 non-null int64
# Frequency                     334019 non-null int64
# StartStation capacity         334019 non-null int64
# EndStation capacity           334019 non-null int64
# distance (geodesic)           334019 non-null float64
# Daily Weather                 334019 non-null object
# Humidity                      334019 non-null float64
# Windspeed                     334019 non-null float64
# Apparent Temperature (Avg)    334019 non-null object
# dtypes: float64(3), int64(6), object(3)
# memory usage: 30.6+ MB

# %%
# Check for empty values and empty strings
np.where(pd.isnull(cycle_usage))
np.where(cycle_usage.applymap(lambda x: x == ''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
cycle_usage.dropna(how='any', thresh=None, subset=None, inplace=True)
cycle_usage.count()
# Out:
# StartStation Id               334019
# Start Date                    334019
# EndStation Id                 334019
# Duration                      334019
# Frequency                     334019
# StartStation capacity         334019
# EndStation capacity           334019
# distance (geodesic)           334019
# Daily Weather                 334019
# Humidity                      334019
# Windspeed                     334019
# Apparent Temperature (Avg)    334019
# dtype: int64

# %% [markdown]
# #### Darksky note:#####
# > Our system is presently very simple: it finds the “worst” weather condition that will happen during the day (4AM to 4AM), and uses the icon for it. The only case where a daily icon will show a *-night value is partly-cloudy-night, and this is done to match the daily summary text. We already have intentions to change this behavior, because it is confusing.
# In the meantime, you can assume that if partly-cloudy-night is the worst weather condition that was found, that it was clear during the day. So you can just treat partly-cloudy-night as an alias for clear-day.

# %%
cycle_usage.groupby(by="Daily Weather").count()
cycle_usage["Daily Weather"].loc[cycle_usage["Daily Weather"]=="partly-cloudy-night"] = "clear-day"

# %%
# Anomaly detection of date format
for index, p in cycle_usage.iterrows():
    if (len(p["Start Date"]) == 19):
        #print(index, p["Start Date"])
        cycle_usage["Start Date"].iloc[index] = p["Start Date"][:15]
        
    elif (len(p["Start Date"]) > 19):
        print("anomaly", index, p["Start Date"])
        cycle_usage["Start Date"].iloc[index] = str(p["Start Date"][:10] + " " +p["Start Date"][-5:])

cycle_usage.dropna(inplace=True)
cycle_usage.count()
# Out:
# StartStation Id               334019
# Start Date                    334019
# EndStation Id                 334019
# Duration                      334019
# Frequency                     334019
# StartStation capacity         334019
# EndStation capacity           334019
# distance (geodesic)           334019
# Daily Weather                 334019
# Humidity                      334019
# Windspeed                     334019
# Apparent Temperature (Avg)    334019
# dtype: int64

# %%
cycle_usage["Start Date"] = cycle_usage["Start Date"].str.slice(0, 16)

# %%
cycle_usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 334019 entries, 0 to 334018
# Data columns (total 12 columns):
# StartStation Id               334019 non-null int64
# Start Date                    334019 non-null object
# EndStation Id                 334019 non-null int64
# Duration                      334019 non-null int64
# Frequency                     334019 non-null int64
# StartStation capacity         334019 non-null int64
# EndStation capacity           334019 non-null int64
# distance (geodesic)           334019 non-null float64
# Daily Weather                 334019 non-null object
# Humidity                      334019 non-null float64
# Windspeed                     334019 non-null float64
# Apparent Temperature (Avg)    334019 non-null object
# dtypes: float64(3), int64(6), object(3)
# memory usage: 33.1+ MB

# %% [markdown]
# Adding weekdays (Monday, Tuesday...)

# %%
#Add weekdays
cycle_usage["Start Date"] =  pd.to_datetime(cycle_usage["Start Date"], format='%d/%m/%Y %H:%M')
cycle_usage['Weekday'] = cycle_usage.apply(lambda row: calendar.day_name[row["Start Date"].weekday()],axis=1)
cycle_usage.head()
# Out:
#    StartStation Id          Start Date  EndStation Id  Duration  Frequency  \
# 0               14 2016-04-02 15:52:00             89       120       1265
# 1               14 2016-04-04 11:21:00             89       120       1265
# 2               14 2016-04-04 11:43:00             89       180       1265
# 3               14 2016-04-06 01:07:00             89       180       1265
# 4               14 2016-04-06 18:46:00             89       180       1265
#
#    StartStation capacity  EndStation capacity  distance (geodesic)  \
# 0                     48                   19              0.41099
# 1                     48                   19              0.41099
# 2                     48                   19              0.41099
# 3                     48                   19              0.41099
# 4                     48                   19              0.41099
#
#        Daily Weather  Humidity  Windspeed Apparent Temperature (Avg)  \
# 0                fog      0.67       2.96                     52,035
# 1  partly-cloudy-day      0.83       3.26                     50,025
# 2  partly-cloudy-day      0.83       3.26                     50,025
# 3  partly-cloudy-day      0.72       5.21                      46,15
# 4  partly-cloudy-day      0.72       5.21                      46,15
#
#      Weekday
# 0   Saturday
# 1     Monday
# 2     Monday
# 3  Wednesday
# 4  Wednesday

# %% [markdown]
# `Meteorologische Jahreszeiten` <br>
# Nördliche Hemisphäre <br>
# Frühling: 1. März bis 31. Mai <br>
# Sommer: 1. Juni bis 31. August <br>
# Herbst: 1. September bis 30. November <br>
# Winter: 1. Dezember bis 28. Februar <br>

# %%
#Add seasons
def seasons(p):
    """Get meteorological season"""
    year = int(str(p["Start Date"])[:4])
    date_m = p["Start Date"]
    if date_m >= datetime(year, 3, 1, 0,0,0) and date_m <= datetime(year, 5, 31, 23,59,59):
        return "Spring"
    elif date_m >= datetime(year, 6, 1, 0,0,0) and date_m <= datetime(year, 8, 31, 23,59,59):
        return "Summer"
    elif date_m >= datetime(year, 9, 1, 0,0,0) and date_m <= datetime(year, 11, 30, 23,59,59):
        return "Autumn"
    elif date_m >= datetime(year, 12, 1, 0,0,0) or date_m < datetime(year, 3, 1, 23,59,59):
        return "Winter"
        
cycle_usage['Season'] = cycle_usage.apply(lambda row: seasons(row),axis=1)
cycle_usage.head()
# Out:
#    StartStation Id          Start Date  EndStation Id  Duration  Frequency  \
# 0               14 2016-04-02 15:52:00             89       120       1265
# 1               14 2016-04-04 11:21:00             89       120       1265
# 2               14 2016-04-04 11:43:00             89       180       1265
# 3               14 2016-04-06 01:07:00             89       180       1265
# 4               14 2016-04-06 18:46:00             89       180       1265
#
#    StartStation capacity  EndStation capacity  distance (geodesic)  \
# 0                     48                   19              0.41099
# 1                     48                   19              0.41099
# 2                     48                   19              0.41099
# 3                     48                   19              0.41099
# 4                     48                   19              0.41099
#
#        Daily Weather  Humidity  Windspeed Apparent Temperature (Avg)  \
# 0                fog      0.67       2.96                     52,035
# 1  partly-cloudy-day      0.83       3.26                     50,025
# 2  partly-cloudy-day      0.83       3.26                     50,025
# 3  partly-cloudy-day      0.72       5.21                      46,15
# 4  partly-cloudy-day      0.72       5.21                      46,15
#
#      Weekday  Season
# 0   Saturday  Spring
# 1     Monday  Spring
# 2     Monday  Spring
# 3  Wednesday  Spring
# 4  Wednesday  Spring

# %% [markdown]
# Add month names

# %%
# Months
def months_names(p):
    """Returns month name"""
    months = {
        1: "January",
        2: "February",
        3: "March",
        4: "April",
        5: "May",
        6: "June",
        7: "July",
        8: "August",
        9: "September",
        10: "October",
        11: "November",
        12: "December"
    }
    return months.get(p["Start Date"].month, "not defined")

cycle_usage["Month"] = cycle_usage.apply(lambda row: months_names(row), axis=1)

# %% [markdown]
# ##### Split Start Date #####
# > Dates are difficult to handle for ML. Idea: splitting to several columns

# %%
#Extract only dd-mm-YYYY
cycle_usage['Date'] = cycle_usage.apply(lambda row: str(row["Start Date"])[:10], axis=1)
cycle_usage['Date'] = pd.to_datetime(cycle_usage.Date, format="%Y/%m/%d")
#Extracting Year
cycle_usage['Year'] = cycle_usage['Date'].dt.year
#Extracting Month
cycle_usage['Month'] = cycle_usage['Date'].dt.month
#Extracting passed years since the date
cycle_usage['Passed_Years'] = date.today().year - cycle_usage['Date'].dt.year
#Extracting passed months since the date
cycle_usage['Passed_Months'] = (date.today().year - cycle_usage['Date'].dt.year) * 12 + date.today().month - cycle_usage['Date'].dt.month
cycle_usage.head()
# Out:
#    StartStation Id          Start Date  EndStation Id  Duration  Frequency  \
# 0               14 2016-04-02 15:52:00             89       120       1265
# 1               14 2016-04-04 11:21:00             89       120       1265
# 2               14 2016-04-04 11:43:00             89       180       1265
# 3               14 2016-04-06 01:07:00             89       180       1265
# 4               14 2016-04-06 18:46:00             89       180       1265
#
#    StartStation capacity  EndStation capacity  distance (geodesic)  \
# 0                     48                   19              0.41099
# 1                     48                   19              0.41099
# 2                     48                   19              0.41099
# 3                     48                   19              0.41099
# 4                     48                   19              0.41099
#
#        Daily Weather  Humidity  Windspeed Apparent Temperature (Avg)  \
# 0                fog      0.67       2.96                     52,035
# 1  partly-cloudy-day      0.83       3.26                     50,025
# 2  partly-cloudy-day      0.83       3.26                     50,025
# 3  partly-cloudy-day      0.72       5.21                      46,15
# 4  partly-cloudy-day      0.72       5.21                      46,15
#
#      Weekday  Season  Month       Date  Year  Passed_Years  Passed_Months
# 0   Saturday  Spring      4 2016-04-02  2016             3             36
# 1     Monday  Spring      4 2016-04-04  2016             3             36
# 2     Monday  Spring      4 2016-04-04  2016             3             36
# 3  Wednesday  Spring      4 2016-04-06  2016             3             36
# 4  Wednesday  Spring      4 2016-04-06  2016             3             36

# %% [markdown]
# Adding new `frequency` column represents rented bikes on station per <b>day</b>.

# %%
# Calculate new frequency of rented bikes
cycle_usage = pd.merge(cycle_usage, cycle_usage.groupby(["Date"])["Humidity"].count().reset_index(name="Rented Bikes"), how='left', on="Date", 
         left_index=False, right_index=False, sort=True)
cycle_usage.head()
# Out:
#    StartStation Id          Start Date  EndStation Id  Duration  Frequency  \
# 0               14 2015-01-04 10:01:00             77       240       1446
# 1               14 2015-01-04 15:17:00             11       240       3019
# 2               14 2015-01-04 19:45:00             11       240       3019
# 3               14 2015-01-04 17:59:00             78       720        906
# 4               14 2015-01-04 15:06:00            374      1080       1414
#
#    StartStation capacity  EndStation capacity  distance (geodesic)  \
# 0                     48                   26             0.726844
# 1                     48                   24             0.671163
# 2                     48                   24             0.671163
# 3                     48                   17             1.767043
# 4                     48                   36             2.961745
#
#   Daily Weather  Humidity  Windspeed Apparent Temperature (Avg) Weekday  \
# 0           fog      0.94       0.55                     36,295  Sunday
# 1           fog      0.94       0.55                     36,295  Sunday
# 2           fog      0.94       0.55                     36,295  Sunday
# 3           fog      0.94       0.55                     36,295  Sunday
# 4           fog      0.94       0.55                     36,295  Sunday
#
#    Season  Month       Date  Year  Passed_Years  Passed_Months  Rented Bikes
# 0  Winter      1 2015-01-04  2015             4             51            33
# 1  Winter      1 2015-01-04  2015             4             51            33
# 2  Winter      1 2015-01-04  2015             4             51            33
# 3  Winter      1 2015-01-04  2015             4             51            33
# 4  Winter      1 2015-01-04  2015             4             51            33

# %%
rm_columns = {
    "StartStation Id",
    "Start Date",
    "StartStation Address",
    "StartStation capacity",
    "EndStation Id",
    "End Date",
    "EndStation Address",
    "EndStation capacity",
    "Duration",
  #  "Frequency",
   # "Humidity",
   # "Windspeed",
   # "Apparent Temperature (Avg)",
    "StartStation Id Used",
    "EndStation Id Used",
    "StartStation latitude",
    "StartStation longitude",
    "EndStation latitude",
    "EndStation longitude",
    "Hourly Weather",
   # "distance (geodesic)",
   # "Daily Weather",
   # 'Rented Bikes' 
}

cycle_usage.drop(columns=rm_columns, inplace=True, errors="ignore")
#cycle_usage.drop_duplicates(inplace=True)
cycle_usage.tail()
# Out:
#         Frequency  distance (geodesic)      Daily Weather  Humidity  \
# 334014       3425             3.588696  partly-cloudy-day      0.67
# 334015         83             4.688374  partly-cloudy-day      0.67
# 334016        254             3.137574  partly-cloudy-day      0.67
# 334017        361             4.136708  partly-cloudy-day      0.67
# 334018        591             1.195863  partly-cloudy-day      0.67
#
#         Windspeed Apparent Temperature (Avg)  Weekday  Season  Month  \
# 334014        3.9                     51,845  Tuesday  Autumn      9
# 334015        3.9                     51,845  Tuesday  Autumn      9
# 334016        3.9                     51,845  Tuesday  Autumn      9
# 334017        3.9                     51,845  Tuesday  Autumn      9
# 334018        3.9                     51,845  Tuesday  Autumn      9
#
#              Date  Year  Passed_Years  Passed_Months  Rented Bikes
# 334014 2018-09-25  2018             1              7           383
# 334015 2018-09-25  2018             1              7           383
# 334016 2018-09-25  2018             1              7           383
# 334017 2018-09-25  2018             1              7           383
# 334018 2018-09-25  2018             1              7           383

# %%
cycle_usage = cycle_usage.drop_duplicates(subset={'Date'})
cycle_usage.sort_values("Rented Bikes", ascending=True).head(1)
# Out:
#         Frequency  distance (geodesic) Daily Weather  Humidity  Windspeed  \
# 272345       3019             0.671163          rain      0.87       4.06
#
#        Apparent Temperature (Avg)  Weekday  Season  Month       Date  Year  \
# 272345                     36,545  Tuesday  Winter     12 2017-12-26  2017
#
#         Passed_Years  Passed_Months  Rented Bikes
# 272345             2             16            12

# %%
cycle_usage.reset_index(drop=True, inplace=True)
cycle_usage.size
# Out:
# 18564

# %%
from datetime import datetime, timedelta
(cycle_usage["Date"][0] - timedelta(1)).strftime('%Y-%m-%d')
# Out:
# '2015-01-03'

# %%
cycle_usage.head()
# Out:
#    Frequency  distance (geodesic)      Daily Weather  Humidity  Windspeed  \
# 0       1446             0.726844                fog      0.94       0.55
# 1        827             2.971281  partly-cloudy-day      0.88       1.59
# 2        827             2.971281  partly-cloudy-day      0.86       2.07
# 3        827             2.971281          clear-day      0.86       4.13
# 4        827             2.971281               rain      0.87       3.60
#
#   Apparent Temperature (Avg)    Weekday  Season  Month       Date  Year  \
# 0                     36,295     Sunday  Winter      1 2015-01-04  2015
# 1                      46,74     Monday  Winter      1 2015-01-05  2015
# 2                      42,15    Tuesday  Winter      1 2015-01-06  2015
# 3                      45,45  Wednesday  Winter      1 2015-01-07  2015
# 4                       46,2   Thursday  Winter      1 2015-01-08  2015
#
#    Passed_Years  Passed_Months  Rented Bikes
# 0             4             51            33
# 1             4             51           281
# 2             4             51           279
# 3             4             51           274
# 4             4             51           161

# %%
cycle_usage.index.max()
# Out:
# 1325

# %% [markdown]
# Add rented bikes `future` feature.

# %%
cycle_usage["Rented Bikes (Future)"] = ""

for index, p in cycle_usage.iterrows():
    if (index-1 < cycle_usage.index.max()-1):
        cycle_usage["Rented Bikes (Future)"].iloc[index-1] = cycle_usage["Rented Bikes"].iloc[index]
    else:
        cycle_usage["Rented Bikes (Future)"].iloc[index-1] = 0

# %%
cycle_usage.tail(100)
# Out:
#       Frequency  distance (geodesic)      Daily Weather  Humidity  Windspeed  \
# 1226       1265             0.410990               wind      0.72      12.47
# 1227        255             3.411596  partly-cloudy-day      0.71      10.55
# 1228       1265             0.410990  partly-cloudy-day      0.79       9.23
# 1229        255             3.411596  partly-cloudy-day      0.49       9.74
# 1230       1265             0.410990          clear-day      0.55       4.72
# 1231        778             4.864494             cloudy      0.53       5.35
# 1232        348             2.980537  partly-cloudy-day      0.51       2.63
# Rented Bikes (Future)         1326
# dtype: int64

# %% [markdown]
# ###### Holidays ######
# Check if that day is a specific holiday?

# %%
#Consider holidays (e.g. Good Friday in UK)
def holiday(p):
    """ Checks if holiday """
    uk_holidays = hd.UK()
    if (p["Date"].date() in uk_holidays):
        return True
    else:
        return False
    
for date2, name in sorted(hd.UK(state='London', years=[2015,2016,2017,2018], observed=False).items()):
    print(date2, name)
    
cycle_usage["Holiday"] = cycle_usage.apply(lambda row: holiday(row), axis=1)            
cycle_usage.head()
# Out:
# 2015-01-01 New Year's Day
# 2015-01-02 New Year Holiday [Scotland]
# 2015-03-17 St. Patrick's Day [Northern Ireland]
# 2015-04-03 Good Friday
# 2015-04-06 Easter Monday [England, Wales, Northern Ireland]
# 2015-05-04 May Day
# 2015-05-25 Spring Bank Holiday
# 2015-07-12 Battle of the Boyne [Northern Ireland]
# 2015-08-03 Summer Bank Holiday [Scotland]
# 2015-08-31 Late Summer Bank Holiday [England, Wales, Northern Ireland]
# 2015-11-30 St. Andrew's Day [Scotland]
# 2015-12-25 Christmas Day
# 2015-12-26 Boxing Day
# 2016-01-01 New Year's Day
# 2016-01-02 New Year Holiday [Scotland]
# 2016-03-17 St. Patrick's Day [Northern Ireland]
# 2016-03-25 Good Friday
# 2016-03-28 Easter Monday [England, Wales, Northern Ireland]
# 2016-05-02 May Day
# 2016-05-30 Spring Bank Holiday
# 2016-07-12 Battle of the Boyne [Northern Ireland]
# 2016-08-01 Summer Bank Holiday [Scotland]
# 2016-08-29 Late Summer Bank Holiday [England, Wales, Northern Ireland]
# 2016-11-30 St. Andrew's Day [Scotland]
# 2016-12-25 Christmas Day
# 2016-12-26 Boxing Day
# 2017-01-01 New Year's Day
# 2017-01-02 New Year Holiday [Scotland]
# 2017-03-17 St. Patrick's Day [Northern Ireland]
# 2017-04-14 Good Friday
# 2017-04-17 Easter Monday [England, Wales, Northern Ireland]
# 2017-05-01 May Day
# 2017-05-29 Spring Bank Holiday
# 2017-07-12 Battle of the Boyne [Northern Ireland]
# 2017-08-07 Summer Bank Holiday [Scotland]
# 2017-08-28 Late Summer Bank Holiday [England, Wales, Northern Ireland]
# 2017-11-30 St. Andrew's Day [Scotland]
# 2017-12-25 Christmas Day
# 2017-12-26 Boxing Day
# 2018-01-01 New Year's Day
# 2018-01-02 New Year Holiday [Scotland]
# 2018-03-17 St. Patrick's Day [Northern Ireland]
# 2018-03-30 Good Friday
# 2018-04-02 Easter Monday [England, Wales, Northern Ireland]
# 2018-05-07 May Day
# 2018-05-28 Spring Bank Holiday
# 2018-07-12 Battle of the Boyne [Northern Ireland]
# 2018-08-06 Summer Bank Holiday [Scotland]
# 2018-08-27 Late Summer Bank Holiday [England, Wales, Northern Ireland]
# 2018-11-30 St. Andrew's Day [Scotland]
# 2018-12-25 Christmas Day
# 2018-12-26 Boxing Day
#    Frequency  distance (geodesic)      Daily Weather  Humidity  Windspeed  \
# 0       1446             0.726844                fog      0.94       0.55
# 1        827             2.971281  partly-cloudy-day      0.88       1.59
# 2        827             2.971281  partly-cloudy-day      0.86       2.07
# 3        827             2.971281          clear-day      0.86       4.13
# 4        827             2.971281               rain      0.87       3.60
#
#   Apparent Temperature (Avg)    Weekday  Season  Month       Date  Year  \
# 0                     36,295     Sunday  Winter      1 2015-01-04  2015
# 1                      46,74     Monday  Winter      1 2015-01-05  2015
# 2                      42,15    Tuesday  Winter      1 2015-01-06  2015
# 3                      45,45  Wednesday  Winter      1 2015-01-07  2015
# 4                       46,2   Thursday  Winter      1 2015-01-08  2015
#
#    Passed_Years  Passed_Months  Rented Bikes  Rented Bikes (Future)  Holiday
# 0             4             51            33                    281    False
# 1             4             51           281                    279    False
# 2             4             51           279                    274    False
# 3             4             51           274                    161    False
# 4             4             51           161                    270    False

# %% [markdown]
# ##### Adding past data #####
# Getting daily weather data from `yesterday`.

# %%
def add_yesterday(cycle_usage):
    """Adds on each day the past day's weather information"""
    from datetime import datetime, timedelta
    rm_columns = {
        "StartStation Id",
        "Start Date",
        "StartStation Address",
        "StartStation capacity",
        "EndStation Id",
        "End Date",
        "EndStation Address",
        "EndStation capacity",
        "Duration",
        "Frequency",
        "Holiday",
        "Humidity",
        "Windspeed",
        "Apparent Temperature (Avg)",
        "StartStation Id Used",
        "EndStation Id Used",
        "StartStation latitude",
        "StartStation longitude",
        "EndStation latitude",
        "EndStation longitude",
        "Hourly Weather",
        "distance (geodesic)",
        "Daily Weather",
        'Rented Bikes',
        'Rented Bikes (Future)',
        'Weekday',
        'Season',
        'Month',
        'Year',
        'Passed_Years',
        'Passed_Months',
        'Daily Weather (Past)',
        #'Yesterday',
        'Date'
    }
    
    cycle_usage["Yesterday"] = ""
    for index, p in cycle_usage.iterrows():
        cycle_usage["Yesterday"].iloc[index] = (cycle_usage["Date"].iloc[index] - timedelta(1)).strftime('%Y-%m-%d')

    df_r = cycle_usage.copy(True)
    df_r.drop(columns=rm_columns, inplace=True, errors="ignore")
    df_r["Yesterday"] = df_r["Yesterday"].astype(str)
    df_w = pd.read_csv("dates and weather_new3.csv", sep=";")
    df_w['Start Date'].replace('\.','-',inplace=True, regex=True)
    df_w["Start Date"] = pd.to_datetime(df_w["Start Date"], format="%d-%m-%Y")
    df_w["Start Date"] = df_w["Start Date"].astype(str)
    df_t = pd.merge(df_r, df_w, left_on="Yesterday", right_on="Start Date", how='left')
    df_t.rename(columns={'Daily Weather' : 'Daily Weather (Past)', 
                         'Humidity' : 'Humidity (Past)',
                         'Windspeed' : 'Windspeed (Past)',
                         'Apparent Temperature (Avg)' : 'Apparent Temperature (Avg) (Past)'}, inplace=True)
 
    cycle_usage = pd.concat([cycle_usage, df_t[["Daily Weather (Past)", "Humidity (Past)", "Windspeed (Past)", "Apparent Temperature (Avg) (Past)"]]], axis=1)
    cycle_usage.drop(df_t.index[:1], inplace=True)
    cycle_usage["Daily Weather (Past)"].loc[cycle_usage["Daily Weather (Past)"]=="partly-cloudy-night"] = "clear-day"
    
    return cycle_usage
    
cycle_usage = add_yesterday(cycle_usage)

# %%
cycle_usage.head()
# Out:
#    Frequency  distance (geodesic)      Daily Weather  Humidity  Windspeed  \
# 1        827             2.971281  partly-cloudy-day      0.88       1.59
# 2        827             2.971281  partly-cloudy-day      0.86       2.07
# 3        827             2.971281          clear-day      0.86       4.13
# 4        827             2.971281               rain      0.87       3.60
# 5       1265             0.410990  partly-cloudy-day      0.81       7.43
#
#   Apparent Temperature (Avg)    Weekday  Season  Month       Date  \
# 1                      46,74     Monday  Winter      1 2015-01-05
# 2                      42,15    Tuesday  Winter      1 2015-01-06
# 3                      45,45  Wednesday  Winter      1 2015-01-07
# 4                       46,2   Thursday  Winter      1 2015-01-08
# 5                     56,085     Friday  Winter      1 2015-01-09
#
#                  ...                  Passed_Years  Passed_Months  \
# 1                ...                             4             51
# 2                ...                             4             51
# 3                ...                             4             51
# 4                ...                             4             51
# 5                ...                             4             51
#
#    Rented Bikes  Rented Bikes (Future)  Holiday   Yesterday  \
# 1           281                    279    False  2015-01-04
# 2           279                    274    False  2015-01-05
# 3           274                    161    False  2015-01-06
# 4           161                    270    False  2015-01-07
# 5           270                     62    False  2015-01-08
#
#   Daily Weather (Past) Humidity (Past)  Windspeed (Past)  \
# 1                  fog            0.94              0.55
# 2    partly-cloudy-day            0.88              1.59
# 3    partly-cloudy-day            0.86              2.07
# 4            clear-day            0.86              4.13
# 5                 rain            0.87              3.60
#
#    Apparent Temperature (Avg) (Past)
# 1                             36,295
# 2                              46,74
# 3                              42,15
# 4                              45,45
# 5                               46,2
#
# [5 rows x 21 columns]

# %%
ol = ["Month", "Season", "Weekday", "Holiday", "Daily Weather","Daily Weather (Past)", "Humidity", "Humidity (Past)", "Windspeed", "Windspeed (Past)", "Apparent Temperature (Avg)", "Apparent Temperature (Avg) (Past)", "Rented Bikes", "Rented Bikes (Future)"]
cycle_usage = cycle_usage[ol]

# %%
cycle_usage.head()
# Out:
#    Month  Season    Weekday  Holiday      Daily Weather Daily Weather (Past)  \
# 1      1  Winter     Monday    False  partly-cloudy-day                  fog
# 2      1  Winter    Tuesday    False  partly-cloudy-day    partly-cloudy-day
# 3      1  Winter  Wednesday    False          clear-day    partly-cloudy-day
# 4      1  Winter   Thursday    False               rain            clear-day
# 5      1  Winter     Friday    False  partly-cloudy-day                 rain
#
#    Humidity  Humidity (Past)  Windspeed  Windspeed (Past)  \
# 1      0.88             0.94       1.59              0.55
# 2      0.86             0.88       2.07              1.59
# 3      0.86             0.86       4.13              2.07
# 4      0.87             0.86       3.60              4.13
# 5      0.81             0.87       7.43              3.60
#
#   Apparent Temperature (Avg) Apparent Temperature (Avg) (Past)  Rented Bikes  \
# 1                      46,74                            36,295           281
# 2                      42,15                             46,74           279
# 3                      45,45                             42,15           274
# 4                       46,2                             45,45           161
# 5                     56,085                              46,2           270
#
#    Rented Bikes (Future)
# 1                    279
# 2                    274
# 3                    161
# 4                    270
# 5                     62

# %%
cycle_usage.to_csv("features.csv", header=True, index=False)
